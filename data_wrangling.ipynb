# %%
import pandas as pd
import numpy as np

from datetime import datetime

import random

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
zones_df = pd.read_json("data/taxizones.json", orient="index")

# %%
zones_df
# Out:
#       id                     name           boro          cX          cY  \
# 1      1           Newark Airport            EWR  145.388391  528.664351
# 2      2              Jamaica Bay         Queens  764.634396  687.534736
# 3      3  Allerton/Pelham Gardens          Bronx  727.322333  122.409068
# 4      4            Alphabet City      Manhattan  496.483468  453.629476
# 5      5            Arden Heights  Staten Island  119.579529  855.392339
# ..   ...                      ...            ...         ...         ...
# 259  259       Woodlawn/Wakefield          Bronx  718.781423   43.554036
# 260  260                 Woodside         Queens  622.395710  405.462003
# 261  261       World Trade Center      Manhattan  432.234798  487.982836
# 262  262           Yorkville East      Manhattan  550.510228  331.079800
# 263  263           Yorkville West      Manhattan  542.737672  324.224922
#
#          raw_X      raw_Y
# 1   -74.174000  40.691831
# 2   -73.826483  40.624196
# 3   -73.847422  40.864474
# 4   -73.976968  40.723752
# 5   -74.188484  40.552659
# ..         ...        ...
# 259 -73.852215  40.897932
# 260 -73.906306  40.744235
# 261 -74.013024  40.709139
# 262 -73.946648  40.775853
# 263 -73.951010  40.778766
#
# [260 rows x 7 columns]

# %%
def cleaner(df, category):
    new_df = pd.DataFrame()
    if (category == "green"):
        # formatting times
        new_df["pu_time"] = pd.to_datetime(df["lpep_pickup_datetime"], format="%m/%d/%Y %I:%M:%S %p")
        new_df["do_time"] = pd.to_datetime(df["lpep_dropoff_datetime"], format="%m/%d/%Y %I:%M:%S %p")

        # calculating duration
        new_df["duration"] = (new_df["do_time"] - new_df["pu_time"]).dt.total_seconds() / 60 # minutes

        # pulling over other info
        new_df["pu_zone"] = df["PULocationID"]
        new_df["do_zone"] = df["DOLocationID"]
        new_df["distance"] =  df["trip_distance"]

        # calculating total price
        new_df["total_lesstip"] = df["total_amount"] - df["tip_amount"]

        # type = green
        new_df["type"] = "green"

        # pulling in PU, DO data
        new_df = new_df.merge(zones_df, left_on="pu_zone", right_on="id", how="left").drop(["id", "cX", "cY"], axis=1)
        new_df = new_df.rename(columns={"name": "pu_nbhd", "boro": "pu_boro", "raw_X" : "pu_X",  "raw_Y" : "pu_Y"})

        new_df = new_df.merge(zones_df, left_on="do_zone", right_on="id", how="left").drop(["id", "cX", "cY"], axis=1)
        new_df = new_df.rename(columns={"name": "do_nbhd", "boro": "do_boro", "raw_X" : "do_X",  "raw_Y" : "do_Y"})

        # dropping NAs
        new_df = new_df.dropna()
        
    if (category == "yellow"):
        # formatting times
        new_df["pu_time"] = pd.to_datetime(df["tpep_pickup_datetime"], format="%m/%d/%Y %I:%M:%S %p")
        new_df["do_time"] = pd.to_datetime(df["tpep_dropoff_datetime"], format="%m/%d/%Y %I:%M:%S %p")

        # calculating duration
        new_df["duration"] = (new_df["do_time"] - new_df["pu_time"]).dt.total_seconds() / 60 # minutes

        # pulling over other info
        new_df["pu_zone"] = df["PULocationID"]
        new_df["do_zone"] = df["DOLocationID"]
        new_df["distance"] =  df["trip_distance"]

        # calculating total price
        new_df["total_lesstip"] = df["total_amount"] - df["tip_amount"]

        # type = yellow
        new_df["type"] = "yellow"

        # pulling in PU, DO data
        new_df = new_df.merge(zones_df, left_on="pu_zone", right_on="id", how="left").drop(["id", "cX", "cY"], axis=1)
        new_df = new_df.rename(columns={"name": "pu_nbhd", "boro": "pu_boro", "raw_X" : "pu_X",  "raw_Y" : "pu_Y"})

        new_df = new_df.merge(zones_df, left_on="do_zone", right_on="id", how="left").drop(["id", "cX", "cY"], axis=1)
        new_df = new_df.rename(columns={"name": "do_nbhd", "boro": "do_boro", "raw_X" : "do_X",  "raw_Y" : "do_Y"})

        # dropping NAs
        new_df = new_df.dropna()

    return new_df

# %%
green_2017_df = cleaner(\
    pd.read_csv("data/trip_data/2017_green_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'ehail_fee', 'trip_type'], axis=1),\
    "green")

yellow_2017_df = cleaner(\
    pd.read_csv("data/trip_data/2017_yellow_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type'], axis=1),\
    "yellow")

# %%
green_2018_df = cleaner(
    pd.read_csv("data/trip_data/2018_green_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'ehail_fee', 'trip_type'], axis=1),\
    "green")

yellow_2018_df = cleaner(\
    pd.read_csv("data/trip_data/2018_yellow_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type'], axis=1),\
    "yellow")

# %%
green_2019_df = cleaner(
    pd.read_csv("data/trip_data/2019_green_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'ehail_fee', 'trip_type'], axis=1),\
    "green")

yellow_2019_df = cleaner(\
    pd.read_csv("data/trip_data/2019_yellow_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type'], axis=1),\
    "yellow")

# %%
green_2020_df = cleaner(
    pd.read_csv("data/trip_data/2020_green_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'ehail_fee', 'trip_type'], axis=1),\
    "green")

yellow_2020_df = cleaner(\
    pd.read_csv("data/trip_data/2020_yellow_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type'], axis=1),\
    "yellow")

# %%
green_2021_df = cleaner(
    pd.read_csv("data/trip_data/2021_green_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'ehail_fee', 'trip_type'], axis=1),\
    "green")

yellow_2021_df = cleaner(\
    pd.read_csv("data/trip_data/2021_yellow_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type'], axis=1),\
    "yellow")

# %%
green_2022_df = cleaner(
    pd.read_csv("data/trip_data/2022_green_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'ehail_fee', 'trip_type'], axis=1),\
    "green")

yellow_2022_df = cleaner(\
    pd.read_csv("data/trip_data/2022_yellow_tripdata.csv").drop(['VendorID', 'passenger_count', 'RatecodeID', 'store_and_fwd_flag', 'payment_type'], axis=1),\
    "yellow")

# %%
yellow_2022_df
# Out:
#                    pu_time             do_time   duration  pu_zone  do_zone  \
# 0      2022-02-09 00:00:00 2022-02-09 00:42:46  42.766667      162       40
# 1      2022-02-09 00:00:04 2022-02-09 00:16:01  15.950000      138      236
# 2      2022-02-09 00:00:04 2022-02-09 00:20:42  20.633333      138      234
# 3      2022-02-09 00:00:05 2022-02-09 00:10:54  10.816667      249      230
# 4      2022-02-09 00:00:06 2022-02-09 00:08:39   8.550000      234      229
# ...                    ...                 ...        ...      ...      ...
# 106084 2022-02-09 23:59:51 2022-02-10 00:05:42   5.850000      230      141
# 106085 2022-02-09 23:59:53 2022-02-10 00:15:43  15.833333       48      152
# 106086 2022-02-09 23:59:53 2022-02-10 00:05:30   5.616667      114       79
# 106087 2022-02-09 23:59:57 2022-02-10 00:12:28  12.516667      244       74
# 106088 2022-02-09 23:59:58 2022-02-10 00:03:04   3.100000      229      137
#
#         distance  total_lesstip    type                        pu_nbhd  \
# 0          11.24          40.80  yellow                   Midtown East
# 1           8.19          36.10  yellow              LaGuardia Airport
# 2          10.58          36.05  yellow              LaGuardia Airport
# 3           2.70          14.30  yellow                   West Village
# 4           3.03          13.80  yellow                       Union Sq
# ...          ...            ...     ...                            ...
# 106084      1.26          10.30  yellow      Times Sq/Theatre District
# 106085      5.53          21.80  yellow                   Clinton East
# 106086      1.04           9.80  yellow        Greenwich Village South
# 106087      6.04          19.80  yellow       Washington Heights South
# 106088      0.99           8.80  yellow  Sutton Place/Turtle Bay North
#
#           pu_boro       pu_X       pu_Y                        do_nbhd  \
# 0       Manhattan -73.972356  40.756688                Carroll Gardens
# 1          Queens -73.873278  40.774352          Upper East Side North
# 2          Queens -73.873278  40.774352                       Union Sq
# 3       Manhattan -74.002875  40.734576      Times Sq/Theatre District
# 4       Manhattan -73.990458  40.740337  Sutton Place/Turtle Bay North
# ...           ...        ...        ...                            ...
# 106084  Manhattan -73.984196  40.759818                Lenox Hill West
# 106085  Manhattan -73.989845  40.762253                 Manhattanville
# 106086  Manhattan -73.997380  40.728340                   East Village
# 106087  Manhattan -73.941399  40.841709              East Harlem North
# 106088  Manhattan -73.965146  40.756729                       Kips Bay
#
#           do_boro       do_X       do_Y
# 0        Brooklyn -73.995956  40.679199
# 1       Manhattan -73.957012  40.780436
# 2       Manhattan -73.990458  40.740337
# 3       Manhattan -73.984196  40.759818
# 4       Manhattan -73.965146  40.756729
# ...           ...        ...        ...
# 106084  Manhattan -73.959635  40.766948
# 106085  Manhattan -73.953782  40.817975
# 106086  Manhattan -73.985937  40.727620
# 106087  Manhattan -73.937351  40.801170
# 106088  Manhattan -73.976494  40.740439
#
# [104345 rows x 16 columns]

# %%
green_2022_df
# Out:
#                  pu_time             do_time   duration  pu_zone  do_zone  \
# 0    2022-02-09 00:06:08 2022-02-09 00:13:59   7.850000       49       62
# 1    2022-02-09 00:07:40 2022-02-09 00:26:11  18.516667      260      134
# 2    2022-02-09 00:07:49 2022-02-09 00:12:58   5.150000      134      134
# 3    2022-02-09 00:08:38 2022-02-09 00:13:29   4.850000      129      129
# 4    2022-02-09 00:09:16 2022-02-09 00:11:40   2.400000      127      127
# ...                  ...                 ...        ...      ...      ...
# 2504 2022-02-09 23:55:31 2022-02-10 00:21:40  26.150000       74      125
# 2505 2022-02-09 23:57:00 2022-02-10 00:09:00  12.000000       74      238
# 2506 2022-02-09 23:58:20 2022-02-10 00:05:22   7.033333       74       41
# 2507 2022-02-09 23:58:23 2022-02-10 00:02:00   3.616667       75       75
# 2508 2022-02-09 23:59:32 2022-02-10 00:13:10  13.633333       66       66
#
#       distance  total_lesstip   type             pu_nbhd    pu_boro  \
# 0         1.30           8.80  green        Clinton Hill   Brooklyn
# 1         7.77          25.30  green            Woodside     Queens
# 2         0.90           6.80  green         Kew Gardens     Queens
# 3         0.93          12.30  green     Jackson Heights     Queens
# 4         0.55           5.30  green              Inwood  Manhattan
# ...        ...            ...    ...                 ...        ...
# 2504     11.67          38.05  green   East Harlem North  Manhattan
# 2505      2.51          11.05  green   East Harlem North  Manhattan
# 2506      1.38           8.30  green   East Harlem North  Manhattan
# 2507      0.58           7.30  green   East Harlem South  Manhattan
# 2508      6.57          35.30  green  DUMBO/Vinegar Hill   Brooklyn
#
#            pu_X       pu_Y                do_nbhd    do_boro       do_X  \
# 0    -73.962363  40.687967    Crown Heights South   Brooklyn -73.948789
# 1    -73.906306  40.744235            Kew Gardens     Queens -73.828713
# 2    -73.828713  40.708051            Kew Gardens     Queens -73.828713
# 3    -73.885317  40.757312        Jackson Heights     Queens -73.885317
# 4    -73.919306  40.866081                 Inwood  Manhattan -73.919306
# ...         ...        ...                    ...        ...        ...
# 2504 -73.937351  40.801170              Hudson Sq  Manhattan -74.007486
# 2505 -73.937351  40.801170  Upper West Side North  Manhattan -73.973049
# 2506 -73.937351  40.801170         Central Harlem  Manhattan -73.951292
# 2507 -73.945750  40.790011      East Harlem South  Manhattan -73.945750
# 2508 -73.985702  40.702259     DUMBO/Vinegar Hill   Brooklyn -73.985702
#
#            do_Y
# 0     40.666540
# 1     40.708051
# 2     40.708051
# 3     40.757312
# 4     40.866081
# ...         ...
# 2504  40.726290
# 2505  40.791705
# 2506  40.804334
# 2507  40.790011
# 2508  40.702259
#
# [2487 rows x 16 columns]

# %%
yellow_2021_df
# Out:
#                   pu_time             do_time   duration  pu_zone  do_zone  \
# 0     2021-02-10 00:00:01 2021-02-10 00:11:41  11.666667      166       74
# 1     2021-02-10 00:00:02 2021-02-10 00:16:00  15.966667       74      197
# 2     2021-02-10 00:00:08 2021-02-10 00:17:53  17.750000      132      138
# 3     2021-02-10 00:00:13 2021-02-10 00:13:46  13.550000      140       24
# 4     2021-02-10 00:00:18 2021-02-10 00:09:39   9.350000      249      163
# ...                   ...                 ...        ...      ...      ...
# 57850 2021-02-10 23:59:32 2021-02-11 00:19:34  20.033333      237       82
# 57851 2021-02-10 23:59:35 2021-02-11 00:15:03  15.466667      140      202
# 57852 2021-02-10 23:59:37 2021-02-11 00:29:26  29.816667      138      123
# 57853 2021-02-10 23:59:57 2021-02-11 00:07:46   7.816667      161       50
# 57854 2021-02-10 23:59:59 2021-02-11 00:17:04  17.083333      137      112
#
#        distance  total_lesstip    type                pu_nbhd    pu_boro  \
# 0          1.90          11.30  yellow    Morningside Heights  Manhattan
# 1         11.86          56.03  yellow      East Harlem North  Manhattan
# 2         11.61          34.30  yellow            JFK Airport     Queens
# 3          3.70          16.80  yellow        Lenox Hill East  Manhattan
# 4          3.06          14.30  yellow           West Village  Manhattan
# ...         ...            ...     ...                    ...        ...
# 57850      7.75          27.80  yellow  Upper East Side South  Manhattan
# 57851      4.18          18.30  yellow        Lenox Hill East  Manhattan
# 57852     17.81          50.30  yellow      LaGuardia Airport     Queens
# 57853      1.30          11.30  yellow         Midtown Center  Manhattan
# 57854      4.63          20.30  yellow               Kips Bay  Manhattan
#
#             pu_X       pu_Y            do_nbhd    do_boro       do_X  \
# 0     -73.961764  40.809457  East Harlem North  Manhattan -73.937351
# 1     -73.937351  40.801170      Richmond Hill     Queens -73.830924
# 2     -73.786533  40.646985  LaGuardia Airport     Queens -73.873278
# 3     -73.954739  40.765484       Bloomingdale  Manhattan -73.965479
# 4     -74.002875  40.734576      Midtown North  Manhattan -73.977569
# ...          ...        ...                ...        ...        ...
# 57850 -73.965634  40.768615           Elmhurst     Queens -73.877118
# 57851 -73.954739  40.765484   Roosevelt Island  Manhattan -73.949951
# 57852 -73.873278  40.774352          Homecrest   Brooklyn -73.964334
# 57853 -73.977698  40.758028       Clinton West  Manhattan -73.995135
# 57854 -73.976494  40.740439         Greenpoint   Brooklyn -73.949538
#
#             do_Y
# 0      40.801170
# 1      40.694542
# 2      40.774352
# 3      40.801970
# 4      40.764421
# ...          ...
# 57850  40.739496
# 57851  40.761900
# 57852  40.599954
# 57853  40.766238
# 57854  40.729507
#
# [56435 rows x 16 columns]

# %%
green_2021_df
# Out:
#                  pu_time             do_time   duration  pu_zone  do_zone  \
# 0    2021-02-10 00:00:52 2021-02-10 00:28:13  27.350000      169      226
# 1    2021-02-10 00:01:00 2021-02-10 00:14:00  13.000000       71       61
# 2    2021-02-10 00:03:00 2021-02-10 00:35:00  32.000000      220      148
# 3    2021-02-10 00:12:23 2021-02-10 00:26:21  13.966667       75      213
# 4    2021-02-10 00:15:00 2021-02-10 00:32:00  17.000000      212      244
# ...                  ...                 ...        ...      ...      ...
# 3207 2021-02-10 23:45:51 2021-02-11 00:01:38  15.783333      134       82
# 3208 2021-02-10 23:50:28 2021-02-10 23:56:10   5.700000       75      238
# 3209 2021-02-10 23:51:07 2021-02-10 23:58:33   7.433333       42      152
# 3210 2021-02-10 23:51:50 2021-02-10 23:58:23   6.550000       43      263
# 3211 2021-02-10 23:52:57 2021-02-11 00:05:06  12.150000       74      229
#
#       distance  total_lesstip   type                     pu_nbhd    pu_boro  \
# 0        13.24          39.30  green                  Mount Hope      Bronx
# 1         2.59          24.42  green      East Flatbush/Farragut   Brooklyn
# 2        14.26          62.70  green  Spuyten Duyvil/Kingsbridge      Bronx
# 3         6.52          20.80  green           East Harlem South  Manhattan
# 4         6.79          36.00  green          Soundview/Bruckner      Bronx
# ...        ...            ...    ...                         ...        ...
# 3207      3.61          16.30  green                 Kew Gardens     Queens
# 3208      1.27           7.80  green           East Harlem South  Manhattan
# 3209      0.99           7.80  green        Central Harlem North  Manhattan
# 3210      1.44          11.05  green                Central Park  Manhattan
# 3211      3.61          16.55  green           East Harlem North  Manhattan
#
#            pu_X       pu_Y                        do_nbhd    do_boro  \
# 0    -73.905122  40.849058                      Sunnyside     Queens
# 1    -73.937966  40.644288            Crown Heights North   Brooklyn
# 2    -73.910665  40.882403                Lower East Side  Manhattan
# 3    -73.945750  40.790011          Soundview/Castle Hill      Bronx
# 4    -73.869680  40.827902       Washington Heights South  Manhattan
# ...         ...        ...                            ...        ...
# 3207 -73.828713  40.708051                       Elmhurst     Queens
# 3208 -73.945750  40.790011          Upper West Side North  Manhattan
# 3209 -73.940772  40.818258                 Manhattanville  Manhattan
# 3210 -73.965554  40.782478                 Yorkville West  Manhattan
# 3211 -73.937351  40.801170  Sutton Place/Turtle Bay North  Manhattan
#
#            do_X       do_Y
# 0    -73.924673  40.737699
# 1    -73.939287  40.674469
# 2    -73.990896  40.718938
# 3    -73.838358  40.823325
# 4    -73.941399  40.841709
# ...         ...        ...
# 3207 -73.877118  40.739496
# 3208 -73.973049  40.791705
# 3209 -73.953782  40.817975
# 3210 -73.951010  40.778766
# 3211 -73.965146  40.756729
#
# [3188 rows x 16 columns]

# %%
yellow_2020_df
# Out:
#                    pu_time             do_time   duration  pu_zone  do_zone  \
# 0      2020-02-12 00:00:00 2020-02-12 00:16:43  16.716667      125       25
# 1      2020-02-12 00:00:00 2020-02-12 00:06:08   6.133333      233      140
# 3      2020-02-12 00:00:01 2020-02-12 00:22:18  22.283333       90       49
# 4      2020-02-12 00:00:01 2020-02-12 00:20:44  20.716667      234       24
# 5      2020-02-12 00:00:02 2020-02-12 00:11:22  11.333333       79      144
# ...                    ...                 ...        ...      ...      ...
# 236423 2020-02-12 23:59:57 2020-02-13 00:06:19   6.366667      230      186
# 236424 2020-02-12 23:59:57 2020-02-13 00:37:19  37.366667      138       11
# 236425 2020-02-12 23:59:58 2020-02-13 00:09:52   9.900000      107      234
# 236426 2020-02-12 23:59:59 2020-02-13 00:35:04  35.083333      132      257
# 236427 2020-02-12 23:59:59 2020-02-13 00:08:43   8.733333      246      143
#
#         distance  total_lesstip    type                    pu_nbhd    pu_boro  \
# 0           3.67           18.3  yellow                  Hudson Sq  Manhattan
# 1           1.30           10.3  yellow        UN/Turtle Bay South  Manhattan
# 3           5.75           24.3  yellow                   Flatiron  Manhattan
# 4           5.53           23.3  yellow                   Union Sq  Manhattan
# 5           1.70           13.3  yellow               East Village  Manhattan
# ...          ...            ...     ...                        ...        ...
# 236423      0.93            9.8  yellow  Times Sq/Theatre District  Manhattan
# 236424     25.24           67.3  yellow          LaGuardia Airport     Queens
# 236425      1.13           11.8  yellow                   Gramercy  Manhattan
# 236426     26.60           70.8  yellow                JFK Airport     Queens
# 236427      2.40           13.3  yellow  West Chelsea/Hudson Yards  Manhattan
#
#              pu_X       pu_Y                       do_nbhd    do_boro  \
# 0      -74.007486  40.726290                   Boerum Hill   Brooklyn
# 1      -73.970451  40.749919               Lenox Hill East  Manhattan
# 3      -73.996972  40.742279                  Clinton Hill   Brooklyn
# 4      -73.990458  40.740337                  Bloomingdale  Manhattan
# 5      -73.985937  40.727620           Little Italy/NoLiTa  Manhattan
# ...           ...        ...                           ...        ...
# 236423 -73.984196  40.759818  Penn Station/Madison Sq West  Manhattan
# 236424 -73.873278  40.774352                    Bath Beach   Brooklyn
# 236425 -73.984052  40.736824                      Union Sq  Manhattan
# 236426 -73.786533  40.646985               Windsor Terrace   Brooklyn
# 236427 -74.004015  40.753309           Lincoln Square West  Manhattan
#
#              do_X       do_Y
# 0      -73.986114  40.685634
# 1      -73.954739  40.765484
# 3      -73.962363  40.687967
# 4      -73.965479  40.801970
# 5      -73.996919  40.720889
# ...           ...        ...
# 236423 -73.992438  40.748497
# 236424 -74.007488  40.604273
# 236425 -73.990458  40.740337
# 236426 -73.977983  40.653612
# 236427 -73.987645  40.775965
#
# [234260 rows x 16 columns]

# %%
green_2020_df
# Out:
#                   pu_time             do_time   duration  pu_zone  do_zone  \
# 0     2020-02-12 00:00:28 2020-02-12 00:12:14  11.766667      244      239
# 1     2020-02-12 00:00:40 2020-02-12 00:09:08   8.466667       82      129
# 2     2020-02-12 00:00:42 2020-02-12 00:09:14   8.533333       82       70
# 3     2020-02-12 00:00:42 2020-02-12 00:15:00  14.300000       65      224
# 4     2020-02-12 00:01:00 2020-02-12 00:27:00  26.000000       97       55
# ...                   ...                 ...        ...      ...      ...
# 14959 2020-02-12 23:59:19 2020-02-13 00:09:48  10.483333      244      127
# 14960 2020-02-12 23:59:25 2020-02-13 00:15:19  15.900000       82       92
# 14961 2020-02-12 23:59:38 2020-02-13 00:13:34  13.933333      152       48
# 14962 2020-02-12 23:59:55 2020-02-13 00:12:05  12.166667       41      239
# 14963 2020-02-12 23:59:57 2020-02-13 00:04:33   4.600000       74       75
#
#        distance  total_lesstip   type                      pu_nbhd    pu_boro  \
# 0          5.27          20.05  green     Washington Heights South  Manhattan
# 1          1.50           9.30  green                     Elmhurst     Queens
# 2          1.87           9.80  green                     Elmhurst     Queens
# 3          5.18          21.55  green  Downtown Brooklyn/MetroTech   Brooklyn
# 4         12.67          41.56  green                  Fort Greene   Brooklyn
# ...         ...            ...    ...                          ...        ...
# 14959      3.23          12.80  green     Washington Heights South  Manhattan
# 14960      6.16          20.80  green                     Elmhurst     Queens
# 14961      4.85          21.05  green               Manhattanville  Manhattan
# 14962      2.89          15.55  green               Central Harlem  Manhattan
# 14963      0.49           6.30  green            East Harlem North  Manhattan
#
#             pu_X       pu_Y                         do_nbhd    do_boro  \
# 0     -73.941399  40.841709           Upper West Side South  Manhattan
# 1     -73.877118  40.739496                 Jackson Heights     Queens
# 2     -73.877118  40.739496                   East Elmhurst     Queens
# 3     -73.986086  40.695337  Stuy Town/Peter Cooper Village  Manhattan
# 4     -73.974882  40.690787                    Coney Island   Brooklyn
# ...          ...        ...                             ...        ...
# 14959 -73.941399  40.841709                          Inwood  Manhattan
# 14960 -73.877118  40.739496                        Flushing     Queens
# 14961 -73.953782  40.817975                    Clinton East  Manhattan
# 14962 -73.951292  40.804334           Upper West Side South  Manhattan
# 14963 -73.937351  40.801170               East Harlem South  Manhattan
#
#             do_X       do_Y
# 0     -73.978633  40.783962
# 1     -73.885317  40.757312
# 2     -73.868396  40.763352
# 3     -73.976598  40.731821
# 4     -73.987943  40.576961
# ...          ...        ...
# 14959 -73.919306  40.866081
# 14960 -73.828859  40.761102
# 14961 -73.989845  40.762253
# 14962 -73.978633  40.783962
# 14963 -73.945750  40.790011
#
# [14866 rows x 16 columns]

# %%
yellow_2019_df
# Out:
#                    pu_time             do_time     duration  pu_zone  do_zone  \
# 0      2019-02-13 00:00:00 2019-02-13 00:25:11    25.183333      132       42
# 1      2019-02-13 00:00:00 2019-02-13 09:20:37   560.616667      238      239
# 2      2019-02-13 00:00:00 2019-02-13 15:19:39   919.650000       90       43
# 3      2019-02-13 00:00:00 2019-02-13 22:31:22  1351.366667      161      148
# 4      2019-02-13 00:00:03 2019-02-13 00:23:08    23.083333      129       48
# ...                    ...                 ...          ...      ...      ...
# 267485 2019-02-13 23:59:57 2019-02-14 00:16:09    16.200000      237       79
# 267486 2019-02-13 23:59:58 2019-02-14 00:05:26     5.466667      164      170
# 267487 2019-02-13 23:59:58 2019-02-14 00:11:11    11.216667      234      230
# 267488 2019-02-13 23:59:58 2019-02-14 00:18:33    18.583333      234       41
# 267489 2019-02-13 23:59:59 2019-02-14 00:12:46    12.783333      236      209
#
#         distance  total_lesstip    type                pu_nbhd    pu_boro  \
# 0          18.75          58.56  yellow            JFK Airport     Queens
# 1           0.97           9.80  yellow  Upper West Side North  Manhattan
# 2           3.95          27.30  yellow               Flatiron  Manhattan
# 3           3.22          19.80  yellow         Midtown Center  Manhattan
# 4           5.80          24.80  yellow        Jackson Heights     Queens
# ...          ...            ...     ...                    ...        ...
# 267485      3.98          18.30  yellow  Upper East Side South  Manhattan
# 267486      0.50           9.30  yellow          Midtown South  Manhattan
# 267487      1.80          12.80  yellow               Union Sq  Manhattan
# 267488      5.42          21.80  yellow               Union Sq  Manhattan
# 267489      6.94          24.30  yellow  Upper East Side North  Manhattan
#
#              pu_X       pu_Y                    do_nbhd    do_boro       do_X  \
# 0      -73.786533  40.646985       Central Harlem North  Manhattan -73.940772
# 1      -73.973049  40.791705      Upper West Side South  Manhattan -73.978633
# 2      -73.996972  40.742279               Central Park  Manhattan -73.965554
# 3      -73.977698  40.758028            Lower East Side  Manhattan -73.990896
# 4      -73.885317  40.757312               Clinton East  Manhattan -73.989845
# ...           ...        ...                        ...        ...        ...
# 267485 -73.965634  40.768615               East Village  Manhattan -73.985937
# 267486 -73.985157  40.748575                Murray Hill  Manhattan -73.978492
# 267487 -73.990458  40.740337  Times Sq/Theatre District  Manhattan -73.984196
# 267488 -73.990458  40.740337             Central Harlem  Manhattan -73.951292
# 267489 -73.957012  40.780436                    Seaport  Manhattan -74.003667
#
#              do_Y
# 0       40.818258
# 1       40.783962
# 2       40.782478
# 3       40.718938
# 4       40.762253
# ...           ...
# 267485  40.727620
# 267486  40.747746
# 267487  40.759818
# 267488  40.804334
# 267489  40.709074
#
# [264482 rows x 16 columns]

# %%
green_2019_df
# Out:
#                   pu_time             do_time   duration  pu_zone  do_zone  \
# 0     2019-02-13 00:00:10 2019-02-13 00:07:57   7.783333       42       41
# 1     2019-02-13 00:00:16 2019-02-13 00:18:37  18.350000       75      169
# 2     2019-02-13 00:00:19 2019-02-13 00:03:24   3.083333      181       25
# 3     2019-02-13 00:00:36 2019-02-13 00:23:10  22.566667       41      185
# 4     2019-02-13 00:00:45 2019-02-13 00:05:15   4.500000       82       82
# ...                   ...                 ...        ...      ...      ...
# 21293 2019-02-13 23:58:35 2019-02-14 00:15:04  16.483333       80      129
# 21294 2019-02-13 23:58:57 2019-02-14 00:12:42  13.750000        7       82
# 21295 2019-02-13 23:59:28 2019-02-13 23:59:56   0.466667       82       82
# 21296 2019-02-13 23:59:42 2019-02-14 00:00:16   0.566667       74       74
# 21297 2019-02-13 23:59:44 2019-02-14 00:12:37  12.883333       75      116
#
#        distance  total_lesstip   type               pu_nbhd    pu_boro  \
# 0          1.65            9.3  green  Central Harlem North  Manhattan
# 1          6.47           21.8  green     East Harlem South  Manhattan
# 2          0.77            5.8  green            Park Slope   Brooklyn
# 3          8.98           27.8  green        Central Harlem  Manhattan
# 4          0.75            6.3  green              Elmhurst     Queens
# ...         ...            ...    ...                   ...        ...
# 21293      5.30           20.3  green     East Williamsburg   Brooklyn
# 21294      3.16           13.8  green               Astoria     Queens
# 21295      0.00            3.8  green              Elmhurst     Queens
# 21296      1.60            3.8  green     East Harlem North  Manhattan
# 21297      3.69           13.8  green     East Harlem South  Manhattan
#
#             pu_X       pu_Y            do_nbhd    do_boro       do_X  \
# 0     -73.940772  40.818258     Central Harlem  Manhattan -73.951292
# 1     -73.945750  40.790011         Mount Hope      Bronx -73.905122
# 2     -73.981414  40.670374        Boerum Hill   Brooklyn -73.986114
# 3     -73.951292  40.804334     Pelham Parkway      Bronx -73.854394
# 4     -73.877118  40.739496           Elmhurst     Queens -73.877118
# ...          ...        ...                ...        ...        ...
# 21293 -73.936793  40.715370    Jackson Heights     Queens -73.885317
# 21294 -73.919694  40.761493           Elmhurst     Queens -73.877118
# 21295 -73.877118  40.739496           Elmhurst     Queens -73.877118
# 21296 -73.937351  40.801170  East Harlem North  Manhattan -73.937351
# 21297 -73.945750  40.790011   Hamilton Heights  Manhattan -73.948522
#
#             do_Y
# 0      40.804334
# 1      40.849058
# 2      40.685634
# 3      40.854405
# 4      40.739496
# ...          ...
# 21293  40.757312
# 21294  40.739496
# 21295  40.739496
# 21296  40.801170
# 21297  40.827013
#
# [21142 rows x 16 columns]

# %%
yellow_2018_df
# Out:
#                    pu_time             do_time   duration  pu_zone  do_zone  \
# 0      2018-02-14 23:59:59 2018-02-15 00:09:52   9.883333      189       61
# 1      2018-02-14 23:59:59 2018-02-15 00:13:57  13.966667      229      113
# 2      2018-02-14 23:59:59 2018-02-15 00:04:33   4.566667       50      230
# 3      2018-02-14 23:59:59 2018-02-15 00:13:23  13.400000      138      226
# 4      2018-02-14 23:59:58 2018-02-15 00:46:08  46.166667      100      188
# ...                    ...                 ...        ...      ...      ...
# 321732 2018-02-14 00:00:00 2018-02-14 00:06:12   6.200000      107      162
# 321733 2018-02-14 00:00:00 2018-02-14 00:05:11   5.183333      234      100
# 321734 2018-02-14 00:00:00 2018-02-14 00:18:07  18.116667      164        7
# 321735 2018-02-14 00:00:00 2018-02-14 00:18:19  18.316667      142       79
# 321736 2018-02-14 00:00:00 2018-02-14 00:00:00   0.000000      186      164
#
#         distance  total_lesstip    type                        pu_nbhd  \
# 0           2.10           10.8  yellow               Prospect Heights
# 1           2.80           13.3  yellow  Sutton Place/Turtle Bay North
# 2           0.73            6.3  yellow                   Clinton West
# 3           5.64           19.3  yellow              LaGuardia Airport
# 4           8.30           33.8  yellow               Garment District
# ...          ...            ...     ...                            ...
# 321732      1.75            8.3  yellow                       Gramercy
# 321733      1.00            7.3  yellow                       Union Sq
# 321734      4.69           18.3  yellow                  Midtown South
# 321735      5.44           19.8  yellow            Lincoln Square East
# 321736      1.08           11.3  yellow   Penn Station/Madison Sq West
#
#           pu_boro       pu_X       pu_Y                    do_nbhd    do_boro  \
# 0        Brooklyn -73.967587  40.677636        Crown Heights North   Brooklyn
# 1       Manhattan -73.965146  40.756729    Greenwich Village North  Manhattan
# 2       Manhattan -73.995135  40.766238  Times Sq/Theatre District  Manhattan
# 3          Queens -73.873278  40.774352                  Sunnyside     Queens
# 4       Manhattan -73.988786  40.753513  Prospect-Lefferts Gardens   Brooklyn
# ...           ...        ...        ...                        ...        ...
# 321732  Manhattan -73.984052  40.736824               Midtown East  Manhattan
# 321733  Manhattan -73.990458  40.740337           Garment District  Manhattan
# 321734  Manhattan -73.985157  40.748575                    Astoria     Queens
# 321735  Manhattan -73.981533  40.773634               East Village  Manhattan
# 321736  Manhattan -73.992438  40.748497              Midtown South  Manhattan
#
#              do_X       do_Y
# 0      -73.939287  40.674469
# 1      -73.994305  40.732579
# 2      -73.984196  40.759818
# 3      -73.924673  40.737699
# 4      -73.947442  40.658744
# ...           ...        ...
# 321732 -73.972356  40.756688
# 321733 -73.988786  40.753513
# 321734 -73.919694  40.761493
# 321735 -73.985937  40.727620
# 321736 -73.985157  40.748575
#
# [315694 rows x 16 columns]

# %%
green_2018_df
# Out:
#                   pu_time             do_time   duration  pu_zone  do_zone  \
# 0     2018-02-14 00:00:00 2018-02-14 00:06:56   6.933333       37       37
# 1     2018-02-14 00:00:00 2018-02-14 00:17:59  17.983333       41        3
# 2     2018-02-14 00:00:02 2018-02-14 00:24:01  23.983333       66       80
# 3     2018-02-14 00:00:04 2018-02-14 00:13:20  13.266667       49       80
# 4     2018-02-14 00:00:04 2018-02-14 00:11:02  10.966667       82      160
# ...                   ...                 ...        ...      ...      ...
# 29330 2018-02-14 23:59:29 2018-02-15 00:08:17   8.800000      255       80
# 29331 2018-02-14 23:59:38 2018-02-15 00:17:10  17.533333       42      239
# 29332 2018-02-14 23:59:45 2018-02-15 00:01:29   1.733333       74       41
# 29333 2018-02-14 23:59:45 2018-02-15 00:01:29   1.733333       74       41
# 29334 2018-02-14 23:59:59 2018-02-15 00:18:51  18.866667      255        7
#
#        distance  total_lesstip   type                    pu_nbhd    pu_boro  \
# 0          1.58            8.8  green             Bushwick South   Brooklyn
# 1          9.08           27.8  green             Central Harlem  Manhattan
# 2          4.62           19.8  green         DUMBO/Vinegar Hill   Brooklyn
# 3          2.92           13.8  green               Clinton Hill   Brooklyn
# 4          2.30           11.3  green                   Elmhurst     Queens
# ...         ...            ...    ...                        ...        ...
# 29330      1.41            8.8  green  Williamsburg (North Side)   Brooklyn
# 29331      3.38           15.8  green       Central Harlem North  Manhattan
# 29332      0.32           -4.8  green          East Harlem North  Manhattan
# 29333      0.32            4.8  green          East Harlem North  Manhattan
# 29334      4.70           18.8  green  Williamsburg (North Side)   Brooklyn
#
#             pu_X       pu_Y                  do_nbhd    do_boro       do_X  \
# 0     -73.922240  40.694994           Bushwick South   Brooklyn -73.922240
# 1     -73.951292  40.804334  Allerton/Pelham Gardens      Bronx -73.847422
# 2     -73.985702  40.702259        East Williamsburg   Brooklyn -73.936793
# 3     -73.962363  40.687967        East Williamsburg   Brooklyn -73.936793
# 4     -73.877118  40.739496           Middle Village     Queens -73.880051
# ...          ...        ...                      ...        ...        ...
# 29330 -73.957418  40.718804        East Williamsburg   Brooklyn -73.936793
# 29331 -73.940772  40.818258    Upper West Side South  Manhattan -73.978633
# 29332 -73.937351  40.801170           Central Harlem  Manhattan -73.951292
# 29333 -73.937351  40.801170           Central Harlem  Manhattan -73.951292
# 29334 -73.957418  40.718804                  Astoria     Queens -73.919694
#
#             do_Y
# 0      40.694994
# 1      40.864474
# 2      40.715370
# 3      40.715370
# 4      40.718337
# ...          ...
# 29330  40.715370
# 29331  40.783962
# 29332  40.804334
# 29333  40.804334
# 29334  40.761493
#
# [29247 rows x 16 columns]

# %%
yellow_2017_df
# Out:
#                    pu_time             do_time   duration  pu_zone  do_zone  \
# 1      2017-02-15 00:00:00 2017-02-15 00:13:46  13.766667      237      226
# 2      2017-02-15 00:00:00 2017-02-15 00:00:49   0.816667      148      148
# 3      2017-02-15 00:00:00 2017-02-15 00:24:08  24.133333      164      129
# 4      2017-02-15 00:00:00 2017-02-15 00:05:21   5.350000       97       17
# 5      2017-02-15 00:00:00 2017-02-15 00:10:10  10.166667      142       41
# ...                    ...                 ...        ...      ...      ...
# 347209 2017-02-15 23:59:57 2017-02-16 00:12:55  12.966667       68      238
# 347210 2017-02-15 23:59:58 2017-02-16 00:25:01  25.050000      231       42
# 347211 2017-02-15 23:59:58 2017-02-16 00:01:30   1.533333       75      263
# 347212 2017-02-15 23:59:58 2017-02-16 00:10:02  10.066667      230      166
# 347213 2017-02-15 23:59:59 2017-02-16 00:07:32   7.550000      186      125
#
#         distance  total_lesstip    type                       pu_nbhd  \
# 1           4.10           15.8  yellow         Upper East Side South
# 2           2.10            3.8  yellow               Lower East Side
# 3           6.55           23.3  yellow                 Midtown South
# 4           1.21            7.3  yellow                   Fort Greene
# 5           3.23           12.8  yellow           Lincoln Square East
# ...          ...            ...     ...                           ...
# 347209      4.27           15.3  yellow                  East Chelsea
# 347210      9.20           29.8  yellow          TriBeCa/Civic Center
# 347211      0.70            5.3  yellow             East Harlem South
# 347212      3.45           12.8  yellow     Times Sq/Theatre District
# 347213      1.90            9.3  yellow  Penn Station/Madison Sq West
#
#           pu_boro       pu_X       pu_Y                do_nbhd    do_boro  \
# 1       Manhattan -73.965634  40.768615              Sunnyside     Queens
# 2       Manhattan -73.990896  40.718938        Lower East Side  Manhattan
# 3       Manhattan -73.985157  40.748575        Jackson Heights     Queens
# 4        Brooklyn -73.974882  40.690787                Bedford   Brooklyn
# 5       Manhattan -73.981533  40.773634         Central Harlem  Manhattan
# ...           ...        ...        ...                    ...        ...
# 347209  Manhattan -73.999917  40.748427  Upper West Side North  Manhattan
# 347210  Manhattan -74.007880  40.717773   Central Harlem North  Manhattan
# 347211  Manhattan -73.945750  40.790011         Yorkville West  Manhattan
# 347212  Manhattan -73.984196  40.759818    Morningside Heights  Manhattan
# 347213  Manhattan -73.992438  40.748497              Hudson Sq  Manhattan
#
#              do_X       do_Y
# 1      -73.924673  40.737699
# 2      -73.990896  40.718938
# 3      -73.885317  40.757312
# 4      -73.949905  40.691507
# 5      -73.951292  40.804334
# ...           ...        ...
# 347209 -73.973049  40.791705
# 347210 -73.940772  40.818258
# 347211 -73.951010  40.778766
# 347212 -73.961764  40.809457
# 347213 -74.007486  40.726290
#
# [340626 rows x 16 columns]

# %%
green_2017_df
# Out:
#                   pu_time             do_time   duration  pu_zone  do_zone  \
# 0     2017-02-15 00:00:00 2017-02-15 00:00:00   0.000000      247      247
# 1     2017-02-15 00:00:00 2017-02-15 00:00:00   0.000000       95      134
# 2     2017-02-15 00:00:00 2017-02-15 00:15:45  15.750000        7      173
# 3     2017-02-15 00:00:02 2017-02-15 00:05:50   5.800000      255      112
# 4     2017-02-15 00:00:03 2017-02-15 00:07:38   7.583333       75      238
# ...                   ...                 ...        ...      ...      ...
# 35054 2017-02-15 23:59:40 2017-02-16 00:23:35  23.916667      256       89
# 35055 2017-02-15 23:59:48 2017-02-16 00:01:48   2.000000      145      112
# 35056 2017-02-15 23:59:51 2017-02-16 00:09:41   9.833333      130      122
# 35057 2017-02-15 23:59:57 2017-02-16 00:13:09  13.200000      129       56
# 35058 2017-02-15 23:59:58 2017-02-16 00:23:23  23.416667       66      230
#
#        distance  total_lesstip   type                         pu_nbhd  \
# 0         15.19           76.8  green                  West Concourse
# 1          2.19           15.8  green                    Forest Hills
# 2          3.10           14.8  green                         Astoria
# 3          1.15            7.8  green       Williamsburg (North Side)
# 4          1.26            8.8  green               East Harlem South
# ...         ...            ...    ...                             ...
# 35054      9.03           28.8  green       Williamsburg (South Side)
# 35055      0.66            5.3  green  Long Island City/Hunters Point
# 35056      2.58           11.3  green                         Jamaica
# 35057      2.20           12.3  green                 Jackson Heights
# 35058      7.24           25.8  green              DUMBO/Vinegar Hill
#
#          pu_boro       pu_X       pu_Y                    do_nbhd    do_boro  \
# 0          Bronx -73.924409  40.828988             West Concourse      Bronx
# 1         Queens -73.847669  40.721432                Kew Gardens     Queens
# 2         Queens -73.919694  40.761493               North Corona     Queens
# 3       Brooklyn -73.957418  40.718804                 Greenpoint   Brooklyn
# 4      Manhattan -73.945750  40.790011      Upper West Side North  Manhattan
# ...          ...        ...        ...                        ...        ...
# 35054   Brooklyn -73.959905  40.710880       Flatbush/Ditmas Park   Brooklyn
# 35055     Queens -73.948891  40.745379                 Greenpoint   Brooklyn
# 35056     Queens -73.793980  40.704369                     Hollis     Queens
# 35057     Queens -73.885317  40.757312                     Corona     Queens
# 35058   Brooklyn -73.985702  40.702259  Times Sq/Theatre District  Manhattan
#
#             do_X       do_Y
# 0     -73.924409  40.828988
# 1     -73.828713  40.708051
# 2     -73.863038  40.752579
# 3     -73.949538  40.729507
# 4     -73.973049  40.791705
# ...          ...        ...
# 35054 -73.960968  40.637900
# 35055 -73.949538  40.729507
# 35056 -73.761137  40.710639
# 35057 -73.858845  40.741407
# 35058 -73.984196  40.759818
#
# [34923 rows x 16 columns]

# %%
dict_dfs = {
    'yellow_2017_df' : yellow_2017_df,
    'green_2017_df' : green_2017_df,
    'yellow_2018_df' : yellow_2018_df,
    'green_2018_df' : green_2018_df,
    'yellow_2019_df' : yellow_2019_df,
    'green_2019_df' : green_2019_df,
    'yellow_2020_df' : yellow_2020_df,
    'green_2020_df' : green_2020_df,
    'yellow_2021_df' : yellow_2021_df,
    'green_2021_df' : green_2021_df,
    'yellow_2022_df' : yellow_2022_df,
    'green_2022_df' : green_2022_df
}

summarized_df = pd.DataFrame(list(dict_dfs.keys()))
summarized_df = summarized_df.rename(columns={0: "dataframe"})

# %%
combined_df = pd.DataFrame()

# %%
for idx, row in summarized_df.iterrows():
    summarized_df.loc[idx, 'year'] = row['dataframe'].split("_")[1]
    summarized_df.loc[idx, 'type'] = row['dataframe'].split("_")[0]

    selected = dict_dfs[row['dataframe']]
    selected = selected[selected['distance'] < 50]
    selected = selected[selected['distance'] > 0]
    selected = selected[selected['duration'] > 0]
    selected = selected[selected['duration'] < 120]
    
    combined_df = pd.concat([combined_df, selected], ignore_index=True, sort=False)
    
    described = selected.describe()

    summarized_df.loc[idx, 'size'] = selected.shape[0]

    summarized_df.loc[idx, 'avg_dist'] = described['distance']['mean']
    summarized_df.loc[idx, 'avg_duration'] = described['duration']['mean']
    summarized_df.loc[idx, 'avg_price'] = described['total_lesstip']['mean']

# %%
combined_df
# Out:
#                     pu_time             do_time   duration  pu_zone  do_zone  \
# 0       2017-02-15 00:00:00 2017-02-15 00:13:46  13.766667      237      226
# 1       2017-02-15 00:00:00 2017-02-15 00:00:49   0.816667      148      148
# 2       2017-02-15 00:00:00 2017-02-15 00:24:08  24.133333      164      129
# 3       2017-02-15 00:00:00 2017-02-15 00:05:21   5.350000       97       17
# 4       2017-02-15 00:00:00 2017-02-15 00:10:10  10.166667      142       41
# ...                     ...                 ...        ...      ...      ...
# 1409821 2022-02-09 23:55:31 2022-02-10 00:21:40  26.150000       74      125
# 1409822 2022-02-09 23:57:00 2022-02-10 00:09:00  12.000000       74      238
# 1409823 2022-02-09 23:58:20 2022-02-10 00:05:22   7.033333       74       41
# 1409824 2022-02-09 23:58:23 2022-02-10 00:02:00   3.616667       75       75
# 1409825 2022-02-09 23:59:32 2022-02-10 00:13:10  13.633333       66       66
#
#          distance  total_lesstip    type                pu_nbhd    pu_boro  \
# 0            4.10          15.80  yellow  Upper East Side South  Manhattan
# 1            2.10           3.80  yellow        Lower East Side  Manhattan
# 2            6.55          23.30  yellow          Midtown South  Manhattan
# 3            1.21           7.30  yellow            Fort Greene   Brooklyn
# 4            3.23          12.80  yellow    Lincoln Square East  Manhattan
# ...           ...            ...     ...                    ...        ...
# 1409821     11.67          38.05   green      East Harlem North  Manhattan
# 1409822      2.51          11.05   green      East Harlem North  Manhattan
# 1409823      1.38           8.30   green      East Harlem North  Manhattan
# 1409824      0.58           7.30   green      East Harlem South  Manhattan
# 1409825      6.57          35.30   green     DUMBO/Vinegar Hill   Brooklyn
#
#               pu_X       pu_Y                do_nbhd    do_boro       do_X  \
# 0       -73.965634  40.768615              Sunnyside     Queens -73.924673
# 1       -73.990896  40.718938        Lower East Side  Manhattan -73.990896
# 2       -73.985157  40.748575        Jackson Heights     Queens -73.885317
# 3       -73.974882  40.690787                Bedford   Brooklyn -73.949905
# 4       -73.981533  40.773634         Central Harlem  Manhattan -73.951292
# ...            ...        ...                    ...        ...        ...
# 1409821 -73.937351  40.801170              Hudson Sq  Manhattan -74.007486
# 1409822 -73.937351  40.801170  Upper West Side North  Manhattan -73.973049
# 1409823 -73.937351  40.801170         Central Harlem  Manhattan -73.951292
# 1409824 -73.945750  40.790011      East Harlem South  Manhattan -73.945750
# 1409825 -73.985702  40.702259     DUMBO/Vinegar Hill   Brooklyn -73.985702
#
#               do_Y
# 0        40.737699
# 1        40.718938
# 2        40.757312
# 3        40.691507
# 4        40.804334
# ...            ...
# 1409821  40.726290
# 1409822  40.791705
# 1409823  40.804334
# 1409824  40.790011
# 1409825  40.702259
#
# [1409826 rows x 16 columns]

# %%
# Reshaping the dataframe
reshaped_df = summarized_df.pivot_table(index='year', columns='type', values=['size', 'avg_dist', 'avg_duration', 'avg_price'])

# Flattening multi-index columns
reshaped_df.columns = [f'{col[1]}_{col[0]}' for col in reshaped_df.columns]

# %%
reshaped_df
# Out:
#       green_avg_dist  yellow_avg_dist  green_avg_duration  \
# year
# 2017        2.506196         2.748466           12.386317
# 2018        2.727670         2.668578           13.798930
# 2019        3.551778         2.853891           17.389300
# 2020        3.478307         2.755941           15.475034
# 2021        4.681709         2.646183           19.872936
# 2022        2.744620         2.767077           15.063082
#
#       yellow_avg_duration  green_avg_price  yellow_avg_price  green_size  \
# year
# 2017            14.001268        12.505362         13.795392     34270.0
# 2018            13.789445        13.419084         13.579507     28850.0
# 2019            14.557773        16.422206         16.551220     20744.0
# 2020            13.642709        17.704150         16.101626     14353.0
# 2021            13.159480        23.343340         15.470630      3084.0
# 2022            13.880239        15.024675         15.977080      2357.0
#
#       yellow_size
# year
# 2017     338870.0
# 2018     313753.0
# 2019     262536.0
# 2020     232174.0
# 2021      55659.0
# 2022     103176.0

# %%
reshaped_df.to_csv("data/sum_year_data.csv")

# %%
X = combined_df[['pu_X', 'pu_Y', 'do_X', 'do_Y']]

y_duration = combined_df['duration']
y_dist = combined_df['distance']
y_price = combined_df['total_lesstip']

X_train, X_test, y_duration_train, y_duration_test, y_dist_train, y_dist_test, y_price_train, y_price_test = train_test_split(X, y_duration, y_dist, y_price, test_size=0.2, random_state=500)

duration_model = LinearRegression()
dist_model = LinearRegression()
price_model = LinearRegression()

duration_model.fit(X_train, y_duration_train)
dist_model.fit(X_train, y_dist_train)
price_model.fit(X_train, y_price_train)
# Out:
# LinearRegression()

# %%
y_price_pred = price_model.predict(X_test)
price_rmse = mean_squared_error(y_price_test, y_price_pred, squared=False)
price_rmse
# Out:
# /Users/ahmed/anaconda3/envs/info4390/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 9.510250594094414

# %%
combined_df['delta_X'] = combined_df['do_X'] - combined_df['pu_X']
combined_df['delta_Y'] = combined_df['do_Y'] - combined_df['pu_Y']

X = combined_df[['delta_X', 'delta_Y']]
X_train, X_test, y_duration_train, y_duration_test, y_dist_train, y_dist_test, y_price_train, y_price_test = train_test_split(X, y_duration, y_dist, y_price, test_size=0.2, random_state=500)
duration_model_2 = LinearRegression()
price_model_2 = LinearRegression()

duration_model_2.fit(X_train, y_duration_train)
price_model_2.fit(X_train, y_price_train)
# Out:
# LinearRegression()

# %%
y_price_pred_2 = price_model_2.predict(X_test)
price_rmse = mean_squared_error(y_price_test, y_price_pred_2, squared=False)
price_rmse
# Out:
# /Users/ahmed/anaconda3/envs/info4390/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 10.75743108514695

# %%
# testing the model based on real use case
for i in range(50):
    n = random.randint(1, 1000000)
    target = combined_df.iloc[n]

    pX = target['pu_X']
    pY = target['pu_Y']
    dX = target['do_X']
    dY = target['do_Y']

    deX = target['delta_X']
    deY = target['delta_Y']

    # duration
    du_coef = duration_model_2.coef_
    du_int = duration_model_2.intercept_

    du_calc = (deX * du_coef[0]) + (deY * du_coef[1]) + du_int

    print(target['pu_nbhd'], target['do_nbhd'])
    print("DURATION: ", du_calc, ",", target['duration'], ",", "\t(", target['duration'] - du_calc, ")")

    # duration
    price_coef = price_model.coef_
    price_int = price_model.intercept_
    price2_coef = price_model_2.coef_
    price2_int = price_model_2.intercept_

    price_calc = ((deX * price2_coef[0]) + (deY * price2_coef[1]) + price2_int)

    print("PRICE: ", price_calc, ",", target['total_lesstip'], ",", "\t(", target['total_lesstip'] - price_calc, ")")
    print("\n")
# Out:
# Midtown Center Midtown South
# DURATION:  14.337801295009266 , 9.316666666666666 , 	( -5.021134628342599 )
# PRICE:  15.250139239476848 , 10.8 , 	( -4.450139239476847 )
#
#
# Meatpacking/West Village West Manhattan Valley
# DURATION:  11.969960744572191 , 30.0 , 	( 18.03003925542781 )
# PRICE:  13.18792350018318 , 23.3 , 	( 10.11207649981682 )
#
#
# Gowanus Homecrest
# DURATION:  14.33517749484779 , 14.783333333333333 , 	( 0.44815583848554397 )
# PRICE:  13.580836678053128 , 19.3 , 	( 5.719163321946873 )
#
#
# Kips Bay Midtown South
# DURATION:  14.117298468979318 , 2.55 , 	( -11.567298468979317 )
# PRICE:  15.339870520777298 , 4.3 , 	( -11.0398705207773 )
#
#
# Union Sq Midtown North
# DURATION:  13.29609060049803 , 24.766666666666666 , 	( 11.470576066168636 )
# PRICE:  14.386891423744036 , 16.8 , 	( 2.413108576255965 )
#
#
# Midtown East Murray Hill
# DURATION:  14.294132218383155 , 11.05 , 	( -3.244132218383154 )
# PRICE:  15.190723315617332 , 9.3 , 	( -5.890723315617331 )
#
#
# Midtown North Lincoln Square East
# DURATION:  13.972869661925465 , 6.916666666666667 , 	( -7.056202995258798 )
# PRICE:  15.1273664073342 , 9.8 , 	( -5.3273664073342 )
#
#
# Murray Hill Co-Op City
# DURATION:  8.0554859533915 , 60.95 , 	( 52.894514046608506 )
# PRICE:  8.315007361177958 , 57.06 , 	( 48.74499263882204 )
#
#
# Battery Park City TriBeCa/Civic Center
# DURATION:  13.689268696181953 , 5.033333333333333 , 	( -8.65593536284862 )
# PRICE:  14.564908367066273 , 6.3 , 	( -8.264908367066273 )
#
#
# Yorkville West Sutton Place/Turtle Bay North
# DURATION:  14.702397129804144 , 13.466666666666667 , 	( -1.235730463137477 )
# PRICE:  15.530313395178954 , 11.8 , 	( -3.7303133951789533 )
#
#
# East Chelsea Flatiron
# DURATION:  14.004695784433666 , 5.583333333333333 , 	( -8.421362451100332 )
# PRICE:  14.781400006471438 , 6.3 , 	( -8.48140000647144 )
#
#
# Upper East Side South Central Park
# DURATION:  13.794849672121014 , 6.95 , 	( -6.844849672121014 )
# PRICE:  14.951783667673897 , 7.8 , 	( -7.1517836676738975 )
#
#
# Upper East Side South Woodside
# DURATION:  12.720468297684551 , 17.15 , 	( 4.4295317023154475 )
# PRICE:  12.169860017683579 , 16.8 , 	( 4.630139982316422 )
#
#
# Midtown North Midtown East
# DURATION:  13.965335699574018 , 5.65 , 	( -8.315335699574018 )
# PRICE:  14.674704131911842 , 7.8 , 	( -6.874704131911842 )
#
#
# Lower East Side Financial District North
# DURATION:  14.627214620021636 , 10.183333333333334 , 	( -4.443881286688303 )
# PRICE:  15.662462846780793 , 10.3 , 	( -5.362462846780792 )
#
#
# East Village SoHo
# DURATION:  14.478726070220647 , 7.05 , 	( -7.428726070220647 )
# PRICE:  15.633351151924428 , 8.3 , 	( -7.333351151924427 )
#
#
# Lenox Hill East Lenox Hill East
# DURATION:  13.99689036820251 , 2.716666666666667 , 	( -11.280223701535844 )
# PRICE:  14.928099797940066 , 5.8 , 	( -9.128099797940067 )
#
#
# East Village Alphabet City
# DURATION:  13.806537510192477 , 3.6333333333333333 , 	( -10.173204176859144 )
# PRICE:  14.510725238752027 , 6.3 , 	( -8.210725238752026 )
#
#
# West Chelsea/Hudson Yards Manhattanville
# DURATION:  11.686489666407201 , 13.533333333333333 , 	( 1.8468436669261319 )
# PRICE:  12.761160684801338 , 20.3 , 	( 7.538839315198663 )
#
#
# Garment District Inwood
# DURATION:  10.467914464502368 , 22.85 , 	( 12.382085535497634 )
# PRICE:  11.976558209981581 , 30.3 , 	( 18.32344179001842 )
#
#
# Midtown East Little Italy/NoLiTa
# DURATION:  15.186849332348514 , 22.166666666666668 , 	( 6.979817334318154 )
# PRICE:  15.979425239903033 , 15.8 , 	( -0.17942523990303272 )
#
#
# Upper East Side North Lenox Hill West
# DURATION:  14.263279803411745 , 10.233333333333333 , 	( -4.0299464700784124 )
# PRICE:  15.021277677492545 , 8.8 , 	( -6.2212776774925445 )
#
#
# Boerum Hill Park Slope
# DURATION:  14.087876426462708 , 12.333333333333334 , 	( -1.7545430931293744 )
# PRICE:  14.683257478619469 , 11.8 , 	( -2.883257478619468 )
#
#
# Upper East Side North Upper East Side North
# DURATION:  13.99689036820251 , 10.883333333333333 , 	( -3.113557034869178 )
# PRICE:  14.928099797940066 , 10.299999999999999 , 	( -4.628099797940067 )
#
#
# Flatiron Lenox Hill East
# DURATION:  12.503616683800233 , 29.466666666666665 , 	( 16.96304998286643 )
# PRICE:  13.044729269571512 , 21.3 , 	( 8.255270730428489 )
#
#
# JFK Airport Lincoln Square East
# DURATION:  17.52176754987666 , 58.583333333333336 , 	( 41.06156578345667 )
# PRICE:  24.085751565989685 , 62.839999999999996 , 	( 38.75424843401031 )
#
#
# Central Park Lincoln Square East
# DURATION:  14.562809473935745 , 13.983333333333333 , 	( -0.5794761406024129 )
# PRICE:  15.64055043062536 , 12.8 , 	( -2.8405504306253597 )
#
#
# Garment District Lenox Hill East
# DURATION:  12.890129931437002 , 27.9 , 	( 15.009870068562996 )
# PRICE:  13.396444291770068 , 20.8 , 	( 7.403555708229932 )
#
#
# East Chelsea Greenwich Village South
# DURATION:  14.216813663239739 , 9.083333333333334 , 	( -5.133480329906405 )
# PRICE:  14.772533263179785 , 8.799999999999999 , 	( -5.972533263179786 )
#
#
# Manhattan Valley East Harlem North
# DURATION:  13.105065074091456 , 13.516666666666667 , 	( 0.41160159257521123 )
# PRICE:  13.52668438862867 , 12.8 , 	( -0.7266843886286694 )
#
#
# Crown Heights South Midwood
# DURATION:  14.874900551679952 , 16.066666666666666 , 	( 1.1917661149867147 )
# PRICE:  15.205096007321279 , 16.8 , 	( 1.5949039926787218 )
#
#
# Lincoln Square East Prospect-Lefferts Gardens
# DURATION:  14.717521063252041 , 71.43333333333334 , 	( 56.715812270081294 )
# PRICE:  13.1439387938027 , 46.8 , 	( 33.65606120619729 )
#
#
# Union Sq Greenwich Village North
# DURATION:  14.214275370201822 , 7.266666666666667 , 	( -6.947608703535155 )
# PRICE:  15.088512120556622 , 10.8 , 	( -4.2885121205566215 )
#
#
# Clinton East Midtown South
# DURATION:  14.065419958249363 , 12.75 , 	( -1.3154199582493629 )
# PRICE:  14.686948864888675 , 16.25 , 	( 1.5630511351113245 )
#
#
# Union Sq Upper East Side South
# DURATION:  12.908191484569246 , 16.816666666666666 , 	( 3.908475182097421 )
# PRICE:  13.850023530719042 , 16.8 , 	( 2.9499764692809585 )
#
#
# Clinton East Washington Heights South
# DURATION:  11.522359626783704 , 22.133333333333333 , 	( 10.610973706549629 )
# PRICE:  12.87204317975003 , 23.8 , 	( 10.927956820249971 )
#
#
# Chinatown East Williamsburg
# DURATION:  12.271380836882146 , 10.8 , 	( -1.4713808368821457 )
# PRICE:  12.13100006446992 , 12.799999999999999 , 	( 0.6689999355300795 )
#
#
# Jackson Heights Long Island City/Queens Plaza
# DURATION:  15.399644941769285 , 10.966666666666667 , 	( -4.432978275102618 )
# PRICE:  17.183739560532928 , 10.8 , 	( -6.383739560532927 )
#
#
# Upper East Side North Upper East Side South
# DURATION:  14.403877461493263 , 12.983333333333333 , 	( -1.4205441281599303 )
# PRICE:  15.298646225441871 , 12.3 , 	( -2.9986462254418704 )
#
#
# Upper East Side South Murray Hill
# DURATION:  14.650476665683447 , 15.616666666666667 , 	( 0.9661900009832198 )
# PRICE:  15.474195542614098 , 11.8 , 	( -3.674195542614097 )
#
#
# Lenox Hill West Midtown East
# DURATION:  14.493832473584321 , 5.183333333333334 , 	( -9.310499140250988 )
# PRICE:  15.48894057288616 , 6.8 , 	( -8.68894057288616 )
#
#
# UN/Turtle Bay South Union Sq
# DURATION:  14.683939209528052 , 12.016666666666667 , 	( -2.667272542861385 )
# PRICE:  15.823078162435717 , 12.3 , 	( -3.5230781624357164 )
#
#
# Bloomingdale Manhattanville
# DURATION:  13.445249584911787 , 6.166666666666667 , 	( -7.27858291824512 )
# PRICE:  14.425381813424181 , 9.3 , 	( -5.12538181342418 )
#
#
# Midtown East Murray Hill
# DURATION:  14.294132218383155 , 7.566666666666666 , 	( -6.727465551716488 )
# PRICE:  15.190723315617332 , 9.3 , 	( -5.890723315617331 )
#
#
# JFK Airport Murray Hill
# DURATION:  17.81147543770586 , 41.0 , 	( 23.18852456229414 )
# PRICE:  23.895712808244593 , 58.56 , 	( 34.664287191755406 )
#
#
# Upper East Side North Upper East Side South
# DURATION:  14.403877461493263 , 10.116666666666667 , 	( -4.287210794826596 )
# PRICE:  15.298646225441871 , 10.8 , 	( -4.49864622544187 )
#
#
# East Harlem South East Harlem South
# DURATION:  13.99689036820251 , 6.15 , 	( -7.84689036820251 )
# PRICE:  14.928099797940066 , 7.3 , 	( -7.628099797940066 )
#
#
# Upper East Side North Midtown East
# DURATION:  14.760221908793556 , 8.016666666666667 , 	( -6.743555242126888 )
# PRICE:  15.582118452438639 , 11.8 , 	( -3.782118452438638 )
#
#
# East Village Financial District South
# DURATION:  15.048403348479404 , 10.133333333333333 , 	( -4.915070015146071 )
# PRICE:  16.048554501921405 , 13.299999999999999 , 	( -2.748554501921406 )
#
#
# Sunnyside Sunnyside
# DURATION:  13.99689036820251 , 4.15 , 	( -9.84689036820251 )
# PRICE:  14.928099797940066 , 6.3 , 	( -8.628099797940067 )

# %%
du_coef
# Out:
# array([-27.43802579, -14.41406507])

# %%
trips_2022_df = pd.concat([yellow_2022_df, green_2022_df], ignore_index=True, sort=False)

# %%
trips_2022_df.to_csv("data/2022_trips.csv")

# %%
trips_2022_df
# Out:
#                    pu_time             do_time   duration  pu_zone  do_zone  \
# 0      2022-02-09 00:00:00 2022-02-09 00:42:46  42.766667      162       40
# 1      2022-02-09 00:00:04 2022-02-09 00:16:01  15.950000      138      236
# 2      2022-02-09 00:00:04 2022-02-09 00:20:42  20.633333      138      234
# 3      2022-02-09 00:00:05 2022-02-09 00:10:54  10.816667      249      230
# 4      2022-02-09 00:00:06 2022-02-09 00:08:39   8.550000      234      229
# ...                    ...                 ...        ...      ...      ...
# 106827 2022-02-09 23:55:31 2022-02-10 00:21:40  26.150000       74      125
# 106828 2022-02-09 23:57:00 2022-02-10 00:09:00  12.000000       74      238
# 106829 2022-02-09 23:58:20 2022-02-10 00:05:22   7.033333       74       41
# 106830 2022-02-09 23:58:23 2022-02-10 00:02:00   3.616667       75       75
# 106831 2022-02-09 23:59:32 2022-02-10 00:13:10  13.633333       66       66
#
#         distance  total_lesstip    type             pu_nbhd    pu_boro  \
# 0          11.24          40.80  yellow        Midtown East  Manhattan
# 1           8.19          36.10  yellow   LaGuardia Airport     Queens
# 2          10.58          36.05  yellow   LaGuardia Airport     Queens
# 3           2.70          14.30  yellow        West Village  Manhattan
# 4           3.03          13.80  yellow            Union Sq  Manhattan
# ...          ...            ...     ...                 ...        ...
# 106827     11.67          38.05   green   East Harlem North  Manhattan
# 106828      2.51          11.05   green   East Harlem North  Manhattan
# 106829      1.38           8.30   green   East Harlem North  Manhattan
# 106830      0.58           7.30   green   East Harlem South  Manhattan
# 106831      6.57          35.30   green  DUMBO/Vinegar Hill   Brooklyn
#
#              pu_X       pu_Y                        do_nbhd    do_boro  \
# 0      -73.972356  40.756688                Carroll Gardens   Brooklyn
# 1      -73.873278  40.774352          Upper East Side North  Manhattan
# 2      -73.873278  40.774352                       Union Sq  Manhattan
# 3      -74.002875  40.734576      Times Sq/Theatre District  Manhattan
# 4      -73.990458  40.740337  Sutton Place/Turtle Bay North  Manhattan
# ...           ...        ...                            ...        ...
# 106827 -73.937351  40.801170                      Hudson Sq  Manhattan
# 106828 -73.937351  40.801170          Upper West Side North  Manhattan
# 106829 -73.937351  40.801170                 Central Harlem  Manhattan
# 106830 -73.945750  40.790011              East Harlem South  Manhattan
# 106831 -73.985702  40.702259             DUMBO/Vinegar Hill   Brooklyn
#
#              do_X       do_Y
# 0      -73.995956  40.679199
# 1      -73.957012  40.780436
# 2      -73.990458  40.740337
# 3      -73.984196  40.759818
# 4      -73.965146  40.756729
# ...           ...        ...
# 106827 -74.007486  40.726290
# 106828 -73.973049  40.791705
# 106829 -73.951292  40.804334
# 106830 -73.945750  40.790011
# 106831 -73.985702  40.702259
#
# [106832 rows x 16 columns]

# %%
trips_2018_df = pd.concat([yellow_2018_df, green_2018_df], ignore_index=True, sort=False)

# %%
trips_2018_df[(trips_2018_df['pu_boro'] == 'Manhattan') | (trips_2018_df['do_boro'] == 'Manhattan')].shape[0] / trips_2018_df.shape[0]
# Out:
# 0.9230506086548135

# %%
trips_2022_df[(trips_2022_df['pu_boro'] == 'Manhattan') | (trips_2022_df['do_boro'] == 'Manhattan')].shape[0] / trips_2022_df.shape[0]
# Out:
# 0.9667608956118017
